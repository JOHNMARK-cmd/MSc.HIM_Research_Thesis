# %%
import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt
import seaborn as sns
import os
import sys
import argparse
import logging
import warnings
import time
import datetime
import json
import re
import random
import string
import requests
import urllib.parse
import urllib.request
import zipfile
import io
import shutil
import subprocess
import tempfile
import glob
import csv


print(pd.__version__)
print(np.__version__)

# %% [markdown]
# # pipeline should look like this
# Raw Data
#    ↓
# Cleaning (per source)
#    ↓
# Standardization (common format)
#    ↓
# Merge / Harmonization
#    ↓
# Feature Engineering
#    ↓
# Modeling
#    ↓
# Evaluation
#
# # target prediction task?
# Examples:
#
# predicting diarrhoea outbreak occurrence
# forecasting case counts per week
# classifying high-risk facilities
# detecting early warning signals

# %% [markdown]
# # The data
# Dataset will be sought from real systems, through web scraping

# %%
pd
